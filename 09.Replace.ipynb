# %%
import pandas as pd

# %%
x = pd.read_csv("C:\\Users\\pankajsingh04\\Documents\\Pandas\\Products.csv")
x
# Out:
#     ProductKey        Country              EnglishProductName  SalesAmount  \
# 0          336          Italy              Road-650 Black, 62     699.0982
# 1          222  United States          Sport-100 Helmet, Blue      34.9900
# 2          540         Canada                    HL Road Tire      32.6000
# 3          536          Italy                ML Mountain Tire      29.9900
# 4          490        Germany  Short-Sleeve Classic Jersey, L      53.9900
# 5          225         Canada                    AWC Logo Cap       8.9900
# 6          390  United States           Road-550-W Yellow, 48    1120.4900
# 7          479          India                Road Bottle Cage       8.9900
# 8          463  United States           Half-Finger Gloves, S      24.4900
# 9          477          India           Water Bottle - 30 oz.       4.9900
# 10         540  United States                    HL Road Tire      32.6000
# ...

# %%
x.replace(to_replace="United States",value="U.S.A.")
# Out:
#     ProductKey  Country              EnglishProductName  SalesAmount  \
# 0          336    Italy              Road-650 Black, 62     699.0982
# 1          222   U.S.A.          Sport-100 Helmet, Blue      34.9900
# 2          540   Canada                    HL Road Tire      32.6000
# 3          536    Italy                ML Mountain Tire      29.9900
# 4          490  Germany  Short-Sleeve Classic Jersey, L      53.9900
# 5          225   Canada                    AWC Logo Cap       8.9900
# 6          390   U.S.A.           Road-550-W Yellow, 48    1120.4900
# 7          479    India                Road Bottle Cage       8.9900
# 8          463   U.S.A.           Half-Finger Gloves, S      24.4900
# 9          477    India           Water Bottle - 30 oz.       4.9900
# 10         540   U.S.A.                    HL Road Tire      32.6000
# 11         214   Canada           Sport-100 Helmet, Red      34.9900
# 12         528    Italy              Mountain Tire Tube       4.9900
# ...

# %%
x.replace([336,222,540],22)
# Out:
#     ProductKey        Country              EnglishProductName  SalesAmount  \
# 0           22          Italy              Road-650 Black, 62     699.0982
# 1           22  United States          Sport-100 Helmet, Blue      34.9900
# 2           22         Canada                    HL Road Tire      32.6000
# 3          536          Italy                ML Mountain Tire      29.9900
# 4          490        Germany  Short-Sleeve Classic Jersey, L      53.9900
# 5          225         Canada                    AWC Logo Cap       8.9900
# 6          390  United States           Road-550-W Yellow, 48    1120.4900
# 7          479          India                Road Bottle Cage       8.9900
# 8          463  United States           Half-Finger Gloves, S      24.4900
# 9          477          India           Water Bottle - 30 oz.       4.9900
# 10          22  United States                    HL Road Tire      32.6000
# ...

# %%
x.replace("[A-Za-z]","Python",regex=True)
# Out:
#     ProductKey                                            Country  \
# 0          336                     PythonPythonPythonPythonPython
# 1          222  PythonPythonPythonPythonPythonPython PythonPyt...
# 2          540               PythonPythonPythonPythonPythonPython
# 3          536                     PythonPythonPythonPythonPython
# 4          490         PythonPythonPythonPythonPythonPythonPython
# 5          225               PythonPythonPythonPythonPythonPython
# 6          390  PythonPythonPythonPythonPythonPython PythonPyt...
# 7          479                     PythonPythonPythonPythonPython
# 8          463  PythonPythonPythonPythonPythonPython PythonPyt...
# 9          477                     PythonPythonPythonPythonPython
# 10         540  PythonPythonPythonPythonPythonPython PythonPyt...
# 11         214               PythonPythonPythonPythonPythonPython
# 12         528                     PythonPythonPythonPythonPython
# ...

# %%
x.replace({"Country":"[A-Za-z]"},"Bharat",regex=True)
# Out:
#     ProductKey                                            Country  \
# 0          336                     BharatBharatBharatBharatBharat
# 1          222  BharatBharatBharatBharatBharatBharat BharatBha...
# 2          540               BharatBharatBharatBharatBharatBharat
# 3          536                     BharatBharatBharatBharatBharat
# 4          490         BharatBharatBharatBharatBharatBharatBharat
# 5          225               BharatBharatBharatBharatBharatBharat
# 6          390  BharatBharatBharatBharatBharatBharat BharatBha...
# 7          479                     BharatBharatBharatBharatBharat
# 8          463  BharatBharatBharatBharatBharatBharat BharatBha...
# 9          477                     BharatBharatBharatBharatBharat
# 10         540  BharatBharatBharatBharatBharatBharat BharatBha...
# 11         214               BharatBharatBharatBharatBharatBharat
# 12         528                     BharatBharatBharatBharatBharat
# ...

# %%
x.replace(222,method="bfill")
# Out:
# C:\Users\pankajsingh04\AppData\Local\Temp\ipykernel_13300\3707346417.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   x.replace(222,method="bfill")
#     ProductKey        Country              EnglishProductName  SalesAmount  \
# 0          336          Italy              Road-650 Black, 62     699.0982
# 1          540  United States          Sport-100 Helmet, Blue      34.9900
# 2          540         Canada                    HL Road Tire      32.6000
# 3          536          Italy                ML Mountain Tire      29.9900
# 4          490        Germany  Short-Sleeve Classic Jersey, L      53.9900
# 5          225         Canada                    AWC Logo Cap       8.9900
# 6          390  United States           Road-550-W Yellow, 48    1120.4900
# 7          479          India                Road Bottle Cage       8.9900
# 8          463  United States           Half-Finger Gloves, S      24.4900
# ...
