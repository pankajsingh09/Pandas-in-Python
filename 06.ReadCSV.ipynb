# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\pankajsingh04\\Documents\\Pandas\\Products.csv")

# %%
data
# Out:
#       OrderDate  ProductKey        Country              EnglishProductName  \
# 0    01/01/2016         336          Italy              Road-650 Black, 62
# 1    01/01/2016         222  United States          Sport-100 Helmet, Blue
# 2    01/01/2016         540         Canada                    HL Road Tire
# 3    01/01/2016         536          Italy                ML Mountain Tire
# 4    01/01/2016         490        Germany  Short-Sleeve Classic Jersey, L
# ..          ...         ...            ...                             ...
# 995  02/02/2016         477         France           Water Bottle - 30 oz.
# 996  02/02/2016         606         Canada              Road-750 Black, 52
# 997  02/02/2016         374  United States              Road-250 Black, 44
# 998  02/02/2016         477          India           Water Bottle - 30 oz.
# 999  02/02/2016         562         Canada         Touring-1000 Yellow, 50
#
# ...

# %%
data1 = pd.read_csv("C:\\Users\\pankajsingh04\\Documents\\Pandas\\Products.csv",nrows=2)
data1
# Out:
#     OrderDate  ProductKey        Country      EnglishProductName  SalesAmount  \
# 0  01/01/2016         336          Italy      Road-650 Black, 62     699.0982
# 1  01/01/2016         222  United States  Sport-100 Helmet, Blue      34.9900
#
#    UnitPrice  OrderQuantity   TaxAmt  TotalProductCost
# 0   699.0982              1  55.9279          413.1463
# 1    34.9900              1   2.7992           13.0863

# %%
data2 = pd.read_csv("C:\\Users\\pankajsingh04\\Documents\\Pandas\\Products.csv",usecols=[0,1,2,3])
data2
# Out:
#       OrderDate  ProductKey        Country              EnglishProductName
# 0    01/01/2016         336          Italy              Road-650 Black, 62
# 1    01/01/2016         222  United States          Sport-100 Helmet, Blue
# 2    01/01/2016         540         Canada                    HL Road Tire
# 3    01/01/2016         536          Italy                ML Mountain Tire
# 4    01/01/2016         490        Germany  Short-Sleeve Classic Jersey, L
# ..          ...         ...            ...                             ...
# 995  02/02/2016         477         France           Water Bottle - 30 oz.
# 996  02/02/2016         606         Canada              Road-750 Black, 52
# 997  02/02/2016         374  United States              Road-250 Black, 44
# 998  02/02/2016         477          India           Water Bottle - 30 oz.
# 999  02/02/2016         562         Canada         Touring-1000 Yellow, 50
#
# [1000 rows x 4 columns]

# %%
data3 = pd.read_csv("C:\\Users\\pankajsingh04\\Documents\\Pandas\\Products.csv",skiprows=[1,2])
data3
# Out:
#       OrderDate  ProductKey        Country              EnglishProductName  \
# 0    01/01/2016         540         Canada                    HL Road Tire
# 1    01/01/2016         536          Italy                ML Mountain Tire
# 2    01/01/2016         490        Germany  Short-Sleeve Classic Jersey, L
# 3    01/01/2016         225         Canada                    AWC Logo Cap
# 4    01/01/2016         390  United States           Road-550-W Yellow, 48
# ..          ...         ...            ...                             ...
# 993  02/02/2016         477         France           Water Bottle - 30 oz.
# 994  02/02/2016         606         Canada              Road-750 Black, 52
# 995  02/02/2016         374  United States              Road-250 Black, 44
# 996  02/02/2016         477          India           Water Bottle - 30 oz.
# 997  02/02/2016         562         Canada         Touring-1000 Yellow, 50
#
# ...

# %%
data3 = pd.read_csv("C:\\Users\\pankajsingh04\\Documents\\Pandas\\Products.csv",index_col="Country")
data3
# Out:
#                 OrderDate  ProductKey              EnglishProductName  \
# Country
# Italy          01/01/2016         336              Road-650 Black, 62
# United States  01/01/2016         222          Sport-100 Helmet, Blue
# Canada         01/01/2016         540                    HL Road Tire
# Italy          01/01/2016         536                ML Mountain Tire
# Germany        01/01/2016         490  Short-Sleeve Classic Jersey, L
# ...                   ...         ...                             ...
# France         02/02/2016         477           Water Bottle - 30 oz.
# Canada         02/02/2016         606              Road-750 Black, 52
# United States  02/02/2016         374              Road-250 Black, 44
# India          02/02/2016         477           Water Bottle - 30 oz.
# Canada         02/02/2016         562         Touring-1000 Yellow, 50
#
#                SalesAmount  UnitPrice  OrderQuantity    TaxAmt  \
# Country
# ...

# %%
data3 = pd.read_csv("C:\\Users\\pankajsingh04\\Documents\\Pandas\\Products.csv",header = 2)
data3
# Out:
#      01/01/2016  222  United States          Sport-100 Helmet, Blue    34.99  \
# 0    01/01/2016  540         Canada                    HL Road Tire    32.60
# 1    01/01/2016  536          Italy                ML Mountain Tire    29.99
# 2    01/01/2016  490        Germany  Short-Sleeve Classic Jersey, L    53.99
# 3    01/01/2016  225         Canada                    AWC Logo Cap     8.99
# 4    01/01/2016  390  United States           Road-550-W Yellow, 48  1120.49
# ..          ...  ...            ...                             ...      ...
# 993  02/02/2016  477         France           Water Bottle - 30 oz.     4.99
# 994  02/02/2016  606         Canada              Road-750 Black, 52   539.99
# 995  02/02/2016  374  United States              Road-250 Black, 44  2443.35
# 996  02/02/2016  477          India           Water Bottle - 30 oz.     4.99
# 997  02/02/2016  562         Canada         Touring-1000 Yellow, 50  2384.07
#
#      34.99.1  1    2.7992    13.0863
# ...

# %%
data3 = pd.read_csv("C:\\Users\\pankajsingh04\\Documents\\Pandas\\Products.csv",names=["col1","col2","col3","col4","col5","col6"],usecols=[1,2,3,4,5,6])
data3
# Out:
#             col1           col2                     col3         col4  \
# 0     ProductKey        Country       EnglishProductName  SalesAmount
# 1            336          Italy       Road-650 Black, 62     699.0982
# 2            222  United States   Sport-100 Helmet, Blue        34.99
# 3            540         Canada             HL Road Tire         32.6
# 4            536          Italy         ML Mountain Tire        29.99
# ...          ...            ...                      ...          ...
# 996          477         France    Water Bottle - 30 oz.         4.99
# 997          606         Canada       Road-750 Black, 52       539.99
# 998          374  United States       Road-250 Black, 44      2443.35
# 999          477          India    Water Bottle - 30 oz.         4.99
# 1000         562         Canada  Touring-1000 Yellow, 50      2384.07
#
#            col5           col6
# 0     UnitPrice  OrderQuantity
# 1      699.0982              1
# ...

# %%
data3 = pd.read_csv("C:\\Users\\pankajsingh04\\Documents\\Pandas\\Products.csv",header=None)
data3
# Out:
#                0           1              2                        3  \
# 0      OrderDate  ProductKey        Country       EnglishProductName
# 1     01/01/2016         336          Italy       Road-650 Black, 62
# 2     01/01/2016         222  United States   Sport-100 Helmet, Blue
# 3     01/01/2016         540         Canada             HL Road Tire
# 4     01/01/2016         536          Italy         ML Mountain Tire
# ...          ...         ...            ...                      ...
# 996   02/02/2016         477         France    Water Bottle - 30 oz.
# 997   02/02/2016         606         Canada       Road-750 Black, 52
# 998   02/02/2016         374  United States       Road-250 Black, 44
# 999   02/02/2016         477          India    Water Bottle - 30 oz.
# 1000  02/02/2016         562         Canada  Touring-1000 Yellow, 50
#
#                 4          5              6         7                 8
# ...

# %%
data3 = pd.read_csv("C:\\Users\\pankajsingh04\\Documents\\Pandas\\Products.csv",dtype={"ProductKey":"float"})
data3
# Out:
#       OrderDate  ProductKey        Country              EnglishProductName  \
# 0    01/01/2016       336.0          Italy              Road-650 Black, 62
# 1    01/01/2016       222.0  United States          Sport-100 Helmet, Blue
# 2    01/01/2016       540.0         Canada                    HL Road Tire
# 3    01/01/2016       536.0          Italy                ML Mountain Tire
# 4    01/01/2016       490.0        Germany  Short-Sleeve Classic Jersey, L
# ..          ...         ...            ...                             ...
# 995  02/02/2016       477.0         France           Water Bottle - 30 oz.
# 996  02/02/2016       606.0         Canada              Road-750 Black, 52
# 997  02/02/2016       374.0  United States              Road-250 Black, 44
# 998  02/02/2016       477.0          India           Water Bottle - 30 oz.
# 999  02/02/2016       562.0         Canada         Touring-1000 Yellow, 50
#
# ...
